# %% [markdown]
# Before we get the data and start exploring it, let's download all the dependencies that we will need.

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.12
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          91 KB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.50-py_0   conda-forge
#     geopy:         1.20.0-py_0 conda-forge
#
#
# ...

# %% [markdown]
# <a id='item1'></a>

# %% [markdown]
# Read the Toronto CSV Data

# %%
M_neighborhoods_df=pd.read_csv('TorontoNeighborhoodsRaw.csv')
M_neighborhoods_df.head()
#M_neighborhoods_df.shape

#===========


#M_neighborhoods_df_cleaned[M_neighborhoods_df_cleaned['Postcode'].isin(['M5A'])]
#M_grouped=M_neighborhoods_df_cleaned.groupby('Postcode').count()
#M_grouped
#M_grouped.shape
#M_neighborhoods_df_cleaned['Postcode'].value_counts()>1
#M_neighborhoods_df_cleaned[M_neighborhoods_df_cleaned['Postcode'].value_counts()>1]
#df2=M_neighborhoods_df_cleaned['Postcode'].value_counts()>1
#df2
#M_neighborhoods_df_cleaned[M_neighborhoods_df_cleaned['Postcode']==df2.index & df2]
#M_neighborhoods_df_cleaned['Postcode'].value_counts().index
#M_grouped.columns
#M_grouped.index
#M_neighborhoods_df_cleaned['Postcode'].value_counts()
#M_neighborhoods_df_cleaned
#df_pc
#df_pc.iloc[:,0]
#df_pc.loc[:,0]
#df_pc1=df_pc.iloc[:,1]>1
#df_pc1
#M_grouped_2=M_grouped[M_grouped.columns[1].>1]
#M_grouped_2
#M_grouped_filtered=M_grouped[M_grouped[M_neighborhoods_df_cleaned.groupby('Postcode').count()>1]]
#repeating_postcode
#M_neighborhoods_df_cleaned.loc[M_neighborhoods_df_cleaned.groupby('Postcode').count()>1,'Neighbourhood']='Dummy2'
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %% [markdown]
# Remove the Borough='Not Assigned'

# %%
NA_borough_index=M_neighborhoods_df[M_neighborhoods_df['Borough']=='Not assigned'].index
M_neighborhoods_df_cleaned=M_neighborhoods_df.drop(index=NA_borough_index,axis=0,inplace=False)
M_neighborhoods_df_cleaned.reset_index(drop=True, inplace=True)
M_neighborhoods_df_cleaned.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M3A        North York         Parkwoods
# 1      M4A        North York  Victoria Village
# 2      M5A  Downtown Toronto      Harbourfront
# 3      M5A  Downtown Toronto       Regent Park
# 4      M6A        North York  Lawrence Heights

# %% [markdown]
# Make Neighborhood=Borough when Neighborhood='Not Assigned'

# %%
M_neighborhoods_df_cleaned = M_neighborhoods_df_cleaned.groupby(['Postcode','Borough'])['Neighbourhood'].apply(', '.join).reset_index()
M_neighborhoods_df_cleaned.head()
# Out:
#   Postcode      Borough                           Neighbourhood
# 0      M1B  Scarborough                          Rouge, Malvern
# 1      M1C  Scarborough  Highland Creek, Rouge Hill, Port Union
# 2      M1E  Scarborough       Guildwood, Morningside, West Hill
# 3      M1G  Scarborough                                  Woburn
# 4      M1H  Scarborough                               Cedarbrae

# %% [markdown]
# Merge the rows with same Postcode and append the Neighborhoods with comma

# %%
M_neighborhoods_df_cleaned.loc[M_neighborhoods_df_cleaned['Neighbourhood']=='Not assigned','Neighbourhood']=M_neighborhoods_df_cleaned['Borough']

M_neighborhoods_df_cleaned
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# ...

# %% [markdown]
# Import the geospatial data

# %%
#!wget -q -O 'toronto_data.json' http://cocl.us/Geospatial_data
#print('Data downloaded!')
df_toronto_geo=pd.read_csv('toronto_data.json')
df_toronto_geo.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# Now merge the two data frames and create a unified view

# %%
df = pd.concat([M_neighborhoods_df_cleaned,df_toronto_geo], axis=1)
df.drop('Postal Code', axis=1, inplace=True)
#df.head()
df
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# ...

# %% [markdown]
# Map

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[43.653654,-79.506944], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(df['Latitude'], df['Longitude'], df['Borough'], df['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
